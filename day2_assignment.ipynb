# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello \
      python")
# Out:
# Hello       python

# %%
print("""(”)….(”)
( ‘ o ‘ )
(”)–(”)
(””’)-(””’)""")
# Out:
# (”)….(”)
# ( ‘ o ‘ )
# (”)–(”)
# (””’)-(””’)

# %%
print("""This is a python""")
# Out:
# This is a python

# %%
print('python\'s world')
# Out:
# python's world

# %%
print("python's world")
# Out:
# python's world

# %%
print("Hello\tpython")
# Out:
# Hello	python

# %%
print("Hello\npython")
# Out:
# Hello
# python

# %%
print("Hello\apython")
# Out:
# Hellopython

# %%
name = "ABC"
age = 20
marks = 95.25
print("The name of person is",name,"marks is",marks,"age is",age)
# Out:
# The name of person is ABC marks is 95.25 age is 20

# %%
print("The name of person is %s marks is %f age of person is %d"%(name,marks,age))
# Out:
# The name of person is ABC marks is 95.250000 age of person is 20

# %%
print("The name of person is %5s marks is %7.2f age of person is %10d"%(name,marks,age))
# Out:
# The name of person is   ABC marks is   95.25 age of person is         20

# %%
print(f"The name of person is {name} marks is {marks} age of person is {age}")
# Out:
# The name of person is ABC marks is 95.25 age of person is 20

# %%
_10 = 5
print(_10)
# Out:
# 5

# %%
x = y = 10
print(x)
# Out:
# 10

# %%
print(y)
# Out:
# 10

# %%
print(id(x))
# Out:
# 94634315381600

# %%
print(id(y))
# Out:
# 94634315381600

# %%
del x

# %%
del y

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
10/2
# Out:
# 5.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
a = 10
b = 20
a == b
# Out:
# False

# %%
c = 10
a == c
# Out:
# True

# %%
10 > 9 and 20 > M
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-517b899b743b> in <module>
# ----> 1 10 > 9 and 20 > M
#
# NameError: name 'M' is not defined

# %%
10 < 9 and 20 > M
# Out:
# False

# %%
10 < 9
# Out:
# False

# %%
not 10 < 9
# Out:
# True

# %%
not True
# Out:
# False

# %%
str1 = "pythonprogramming"

# %%
"a" in str1
# Out:
# True

# %%
"x" in str1
# Out:
# False

# %%
a = 10
b = 10

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 94634315381600

# %%
id(b)
# Out:
# 94634315381600

# %%
x = 1.5
y = 1.5
x is y
# Out:
# False

# %%
id(x)
# Out:
# 139695499924320

# %%
id(y)
# Out:
# 139695499924080

# %%
a = 257 
b = 257

# %%
a is b
# Out:
# False

# %%
10+10/20*4
# Out:
# 12.0

# %%
10/29
# Out:
# 0.3448275862068966

# %%
2**-1
# Out:
# 0.5

# %%
2**2**3
# Out:
# 256

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
10>8>9
# Out:
# False
